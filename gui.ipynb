# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import MinMaxScaler

# %%
# !pip install joblib
from joblib import load
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
data = pd.read_csv('/content/drive/MyDrive/miniproject/3D_dataset_Authentic/ab.csv')

# %%
X= data.iloc[23000:23001,[0,8,16,24,32,40,48,56,64,72,80,88,96]]
print(X)
# Out:
#        ch0/prn     ch0/cdh    ch0/psrn   ch0/rxt      ch0/tow      ch0/cpc  \
# 23000        6  877.731148  23661389.9  492004.5  492004.4211 -125539.9633
#
#           ch0/ec     ch0/lc       ch0/pc    ch0/pip    ch0/pqp    ch0/tcd  \
# 23000  126491.66  104215.53  129285.5877  127774.47  19709.084  880.82666
#
#          ch0/cn0
# 23000  46.069393

# %%
X = np.array(X)
X= X/np.linalg.norm(X)

# %%
print(X)
# Out:
# [[ 2.53450897e-07  3.70769578e-05  9.99500082e-01  2.07831636e-02
#    2.07831603e-02 -5.30303605e-03  5.34323745e-03  4.40225326e-03
#    5.46125803e-03  5.39742567e-03  8.32547503e-04  3.72077178e-05
#    1.94605483e-06]]

# %%
model_zero = load('/content/drive/MyDrive/miniproject/zero.joblib')
y_zero = model_zero.predict(X)
print(y_zero)
# Out:
# [0]

# %%
model_one = load('/content/drive/MyDrive/miniproject/one.joblib')
y_one = model_one.predict(X)
print(y_one)
# Out:
# ['a3']

# %%
model_two = load('/content/drive/MyDrive/miniproject/two.joblib')
y_two = model_two.predict(X)
print(y_two)
# Out:
# ['b0']

# %%
model_three = load('/content/drive/MyDrive/miniproject/three.joblib')
y_three = model_three.predict(X)
print(y_three)
# Out:
# ['c3']

# %%
model_four = load('/content/drive/MyDrive/miniproject/four.joblib')
y_four = model_four.predict(X)
print(y_four)
# Out:
# ['d0']

# %%
model_five = load('/content/drive/MyDrive/miniproject/five.joblib')
y_five = model_five.predict(X)
print(y_five)
# Out:
# ['e1']

# %%
model_six = load('/content/drive/MyDrive/miniproject/six.joblib')
y_six = model_six.predict(X)
print(y_six)
# Out:
# ['f3']

# %%
model_seven = load('/content/drive/MyDrive/miniproject/seven.joblib')
y_seven = model_seven.predict(X)
print(y_seven)
# Out:
# ['g0']

# %%
print(y_zero)
print(y_one)
print(y_two)
print(y_three)
print(y_four)
print(y_five)
print(y_six)
print(y_seven)
# Out:
# [0]
# ['a0']
# ['b0']
# ['c0']
# ['d0']
# ['e0']
# ['f0']
# ['g0']

# %%
# !pip install gradio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 58.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 39.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.2/286.2 kB 25.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.5/140.5 kB 15.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.3/75.3 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.7/129.7 kB 15.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 6.4 MB/s eta 0:00:00
# ...

# %%
import gradio as gr

def spoof(one):
  a = int(one)
  b = a-1
  x = data.iloc[b:a,[0,8,16,24,32,40,48,56,64,72,80,88,96]]
  x = np.array(x)
  c = np.linalg.norm(x)
  if c==0:
    y = "Norm is zero"
  
  else:
    x = x/c
    y = [model_zero.predict(x),model_one.predict(x),model_two.predict(x),model_three.predict(x),model_four.predict(x),model_five.predict(x),model_six.predict(x),model_seven.predict(x)]
  return y
 
iface=gr.Interface(fn=spoof, inputs="text", outputs="text")
iface.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://35f154d8b26fe56e30.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://35f154d8b26fe56e30.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/DT.joblib']
